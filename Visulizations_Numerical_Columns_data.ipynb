# %%
pip install xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import xlrd

# %%
df=pd.read_excel("C:/Users/nr802/Downloads/Machine learning Projects/global_superstore/Global Superstore.xls")

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
# Visualization examples


# 1. Line plot
plt.figure(figsize=(10, 5))
plt.plot(df['Sales'], label='Sales')
plt.title('Line Plot of Sales')
plt.xlabel('Index')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Sales'], df['Profit'], c='green', alpha=0.5)
plt.title('Scatter Plot of Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(df.index[:10], df['Sales'][:10], color='blue')
plt.title('Bar Plot of Sales (First 10 Rows)')
plt.xlabel('Index')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['Discount'], bins=10, color='purple', alpha=0.7)
plt.title('Histogram of Discount')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot([df['Sales'], df['Profit']], labels=['Sales', 'Profit'])
plt.title('Box Plot of Sales and Profit')
plt.ylabel('Value')
plt.show()
# Out:
# C:\Users\nr802\AppData\Local\Temp\ipykernel_17956\4123612926.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['Sales'], df['Profit']], labels=['Sales', 'Profit'])

# %%
plt.figure(figsize=(7, 7))
plt.pie(df['Quantity'][:5], labels=df.index[:5], autopct='%1.1f%%')
plt.title('Pie Chart of Quantity (First 5 Rows)')
plt.show()

# %%
df1=df[['Sales','Profit', 'Shipping Cost']]
df1.corr()
# Out:
#                   Sales    Profit  Shipping Cost
# Sales          1.000000  0.484918       0.768073
# Profit         0.484918  1.000000       0.354441
# Shipping Cost  0.768073  0.354441       1.000000

# %%
import seaborn as sns
plt.figure(figsize=(10, 5))
df1=df[['Sales','Profit', 'Shipping Cost']]
sns.heatmap(df1.corr(),cmap="YlGnBu", annot=True)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
df1.head()
# Out:
#       Sales    Profit  Shipping Cost
# 0  2309.650  762.1845         933.57
# 1  3709.395 -288.7650         923.63
# 2  5175.171  919.9710         915.49
# 3  2892.510  -96.5400         910.16
# 4  2832.960  311.5200         903.04

# %%
sns.pairplot(df)
plt.title('Pairplot of DataFrame Columns')
plt.show()

# %%
#  KDE plot
plt.figure(figsize=(10, 5))
sns.kdeplot(df['Profit'], shade=True, color='orange')
plt.title('KDE Plot of Profit')
plt.xlabel('Profit')
plt.show()
# Out:
# C:\Users\nr802\AppData\Local\Temp\ipykernel_17956\3239829944.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Profit'], shade=True, color='orange')

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(data=df[['Sales', 'Profit']])
plt.title('Violin Plot of Sales and Profit')
plt.ylabel('Value')
plt.show()

# %%
plt.figure(figsize=(10, 5))
x = df.index[:10]
plt.bar(x, df['Sales'][:10], label='Sales', color='blue')
plt.bar(x, df['Profit'][:10], bottom=df['Sales'][:10], label='Profit', color='orange')
plt.title('Stacked Bar Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.fill_between(df.index[:50], df['Sales'][:50], alpha=0.5, label='Sales')
plt.fill_between(df.index[:50], df['Profit'][:50], alpha=0.5, label='Profit')
plt.title('Area Plot of Sales and Profit')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.barh(df.index[:10], df['Shipping Cost'][:10], color='green')
plt.title('Horizontal Bar Plot of Shipping Cost')
plt.xlabel('Shipping Cost')
plt.ylabel('Index')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Sales'][:20], label='Sales', color='blue')
plt.plot(df['Profit'][:20], label='Profit', color='red')
plt.title('Multiple Lines Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
x = np.arange(10)
width = 0.4
plt.figure(figsize=(10, 5))
plt.bar(x - width/2, df['Sales'][:10], width, label='Sales', color='blue')
plt.bar(x + width/2, df['Profit'][:10], width, label='Profit', color='orange')
plt.title('Grouped Bar Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.xticks(x, df.index[:10])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.stackplot(range(len(df)), df["Sales"], df["Profit"], df["Shipping Cost"], labels=["Sales", "Profit", "Shipping Cost"])
plt.legend(loc='upper left')
plt.title("Stackplot Example")
plt.xlabel("Index")
plt.ylabel("Values")
plt.show()

# %%
import math
def radar_chart(data, categories):
    N = len(categories)
    values = data + data[:1]
    angles = [n / float(N) * 2 * math.pi for n in range(N)]
    angles += angles[:1]

    ax = plt.subplot(111, polar=True)
    plt.xticks(angles[:-1], categories)

    ax.plot(angles, values, linewidth=2, linestyle='solid')
    ax.fill(angles, values, alpha=0.4)

categories = ["Sales", "Quantity", "Discount", "Profit", "Shipping Cost"]
data = [df["Sales"].mean(), df["Quantity"].mean(), df["Discount"].mean(), df["Profit"].mean(), df["Shipping Cost"].mean()]
plt.figure(figsize=(8, 8))
radar_chart(data, categories)
plt.title("Radar Chart Example")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Sales"], df["Profit"], marker='o')
for i, txt in enumerate(df["Profit"]):
    plt.annotate(txt, (df["Sales"][i], df["Profit"][i]))
plt.title("Annotated Plot Example")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["Sales"], df["Profit"], df["Quantity"], c='r', marker='o')
ax.set_xlabel("Sales")
ax.set_ylabel("Profit")
ax.set_zlabel("Quantity")
plt.title("3D Scatter Plot Example")
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot 1
axs[0, 0].plot(df["Sales"], label="Sales")
axs[0, 0].set_title("Sales Line Plot")
axs[0, 0].legend()

# Plot 2
axs[0, 1].bar(range(len(df)), df["Profit"], color='orange', label="Profit")
axs[0, 1].set_title("Profit Bar Plot")
axs[0, 1].legend()

# Plot 3
axs[1, 0].scatter(df["Quantity"], df["Shipping Cost"], color='green', label="Shipping Cost vs Quantity")
axs[1, 0].set_title("Scatter Plot")
axs[1, 0].legend()

# Plot 4
axs[1, 1].pie(df["Discount"], labels=range(len(df)), autopct='%1.1f%%', startangle=90)
axs[1, 1].set_title("Discount Pie Chart")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\nr802\AppData\Local\Temp\ipykernel_17956\3689041081.py:22: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# C:\Users\nr802\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Pair Plots
#
# sales & Profit

# %%
sns.pairplot(df, vars=['Sales', 'Profit'])
plt.title('Pair Plot: Sales & Profit')
plt.show()

# %% [markdown]
# Profit & Discount:

# %%
sns.pairplot(df, vars=['Profit', 'Discount'])
plt.title('Pair Plot: Profit & Discount')
plt.show()

# %% [markdown]
# Pie Charts:
#
# Profit by Different Markets:

# %%
market_profit = df.groupby('Market')['Profit'].sum()
market_profit.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Profit Distribution Across Markets')
plt.ylabel('')
plt.show()

# %% [markdown]
# Sales by Different Categories:

# %%
category_sales = df.groupby('Category')['Sales'].sum()
category_sales.plot.pie(autopct='%1.1f%%', startangle=140)
plt.title('Sales Distribution Across Categories')
plt.ylabel('')
plt.show()

# %% [markdown]
# Box Plots:
#
# Sales, Profit, Discount, Shipping Cost, Quantity:

# %%
sns.boxplot(data=df[['Sales', 'Profit', 'Discount', 'Shipping Cost', 'Quantity']])
plt.title('Box Plot of Sales, Profit, Discount, Shipping Cost, and Quantity')
plt.show()

# %% [markdown]
# Histograms:
#
# Sales

# %%
plt.hist(df['Sales'], bins=30, edgecolor='k')
plt.title('Histogram of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Quantity:

# %%
plt.hist(df['Quantity'], bins=30, edgecolor='k')
plt.title('Histogram of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Bar Plot:
#
# Sales for the First 50 Rows

# %%
plt.bar(df.index[:50], df['Sales'][:50])
plt.title('Sales for the First 50 Rows')
plt.xlabel('Index')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Scatter Plot:
#
# Sales vs. Discount

# %%
plt.scatter(df['Discount'], df['Sales'])
plt.title('Scatter Plot: Sales vs. Discount')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Line Plot:
#
# Quantity Over Time:

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.sort_values('Order Date', inplace=True)
plt.plot(df['Order Date'], df['Quantity'])
plt.title('Line Plot of Quantity Over Time')
plt.xlabel('Order Date')
plt.ylabel('Quantity')
plt.show()

# %%
import os

# %%
import matplotlib.pyplot as plt
import seaborn as sns
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('ggplot')  # or any style from plt.style.available

# %%
# Ensure 'Order Date' is in datetime format for time-based plots
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Define styles and palettes
styles = ['ggplot', 'seaborn-darkgrid', 'fivethirtyeight', 'bmh', 'seaborn-dark']
palettes = ['pastel', 'muted', 'bright', 'dark', 'colorblind']

# Set a larger plot size globally for clarity
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Graph 1: Pair Plot - Sales & Profit
plt.style.use(styles[0])
sns.set_palette(palettes[0])
sns.pairplot(df, vars=['Sales', 'Profit'], height=5)
plt.suptitle('Pair Plot: Sales & Profit (Style: ggplot, Palette: pastel)', y=1.02)
plt.show()

# %%
styles = ['seaborn-whitegrid', 'ggplot', 'bmh', 'dark_background']

# %%
plt.style.use(styles[1])

# %%
palettes = ['deep', 'muted', 'pastel', 'dark']
sns.set_palette(palettes[1])

# %%
# Graph : Pair Plot - Profit & Discount
plt.style.use(styles[1])
sns.set_palette(palettes[1])
sns.pairplot(df, vars=['Profit', 'Discount'], height=5)
plt.suptitle('Pair Plot: Profit & Discount (Style: seaborn-darkgrid, Palette: muted)', y=1.02)
plt.show()

# %%
# Graph : Pie Chart - Profit by Market
plt.style.use(styles[2])
market_profit = df.groupby('Market')['Profit'].sum()
market_profit.plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette(palettes[2]))
plt.title('Profit Distribution Across Markets (Style: fivethirtyeight, Palette: bright)')
plt.ylabel('')
plt.show()

# Graph : Pie Chart - Sales by Category
plt.style.use(styles[3])
category_sales = df.groupby('Category')['Sales'].sum()
category_sales.plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette(palettes[3]))
plt.title('Sales Distribution Across Categories (Style: bmh, Palette: dark)')
plt.ylabel('')
plt.show()

# %%
styles = ['seaborn-whitegrid', 'ggplot', 'bmh', 'dark_background']
palettes = ['deep', 'muted', 'pastel', 'dark']
plt.style.use(styles[3])  # Use 'dark_background' (index 3)
sns.set_palette(palettes[3])  # Use 'dark' (index 3)
styles = ['seaborn-whitegrid', 'ggplot', 'bmh', 'dark_background', 'seaborn-darkgrid']
palettes = ['deep', 'muted', 'pastel', 'dark', 'bright']

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
import seaborn as sns
sns.set_style('darkgrid')  # Or any other seaborn style
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
import os

# %%
# Graph : Histogram - Quantity
plt.style.use(styles[1])
sns.set_palette(palettes[1])
sns.histplot(df['Quantity'], kde=True, bins=20, color='orange')
plt.title('Histogram of Quantity (Style: seaborn-darkgrid, Palette: muted)')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# Graph : Bar Plot - Sales for the First 50 Rows
plt.style.use(styles[2])
sns.set_palette(palettes[2])
sns.barplot(x=df.index[:50], y=df['Sales'][:50], color='blue')
plt.title('Sales of First 50 Rows (Style: fivethirtyeight, Palette: bright)')
plt.xlabel('Index')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
# Graph : Scatter Plot - Sales vs Discount
plt.style.use(styles[3])
sns.set_palette(palettes[3])
sns.scatterplot(data=df, x='Sales', y='Discount', hue='Category', alpha=0.7)
plt.title('Scatter Plot: Sales vs Discount (Style: bmh, Palette: dark)')
plt.xlabel('Sales')
plt.ylabel('Discount')
plt.legend(title='Category')
plt.show()
